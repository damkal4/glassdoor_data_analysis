# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cleaned_data.csv')

# %%
df.drop('Unnamed: 0', inplace = True, axis = 1)

# %%
df.describe()
# Out:
#            Rating      Founded      hourly         salary         age  \
# count  407.000000   407.000000  407.000000     407.000000  407.000000
# mean     3.707617  1594.565111    0.019656  115964.488256   69.380835
# std      0.989783   742.186877    0.138986   28653.489296   58.291310
# min     -1.000000    -1.000000    0.000000   64975.000000   -1.000000
# 25%      3.700000  1851.000000    0.000000   95709.000000   18.000000
# 50%      3.900000  1944.000000    0.000000  112288.000000   62.000000
# 75%      4.100000  1971.000000    0.000000  131729.000000  101.000000
# max      5.000000  2019.000000    1.000000  233500.000000  247.000000
#
#            Python         SQL      Pandas    R Studio       Excel         AWS
# count  407.000000  407.000000  407.000000  407.000000  407.000000  407.000000
# mean     0.589681    0.464373    0.004914    0.002457    0.243243    0.181818
# std      0.492497    0.499343    0.070014    0.049568    0.429569    0.386169
# ...

# %%
df.salary.hist()
print('Graph for salary')
# Out:
# Graph for salary

# %%
df.Rating.hist()
print('Graph for rating')
# Out:
# Graph for rating

# %%
df.columns
# Out:
# Index(['Company Name', 'Location', 'Job title', 'Job description',
#        'Salary estimate', 'Rating', 'Company industry', 'Siza',
#        'Type of ownership', 'Founded', 'Sector', 'Revenur', 'hourly', 'salary',
#        'age', 'Python', 'SQL', 'Pandas', 'R Studio', 'Excel', 'AWS'],
#       dtype='object')

# %%
categories = df[['Location',  'Siza', 'Type of ownership', 'Sector', 'Company industry', 'Revenur']]

# %%
for i in categories:
    cat_num = categories[i].value_counts()[:20].sort_values(ascending = False)
    print('Graph for {}'.format(i) )
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# Graph for Location
# Graph for Siza
# Graph for Type of ownership
# Graph for Sector
# Graph for Company industry
# Graph for Revenur

# %%
for i in requirements:
    cat_num = requirements[i].value_counts()[:20].sort_values(ascending = False)
    print('Graph for {}'.format(i) )
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(['No', 'Yes'])
    plt.show()
# Out:
# Graph for Python
# Graph for SQL
# Graph for Pandas
# Graph for R Studio
# Graph for Excel
# Graph for AWS

# %%
plt.rcParams["figure.figsize"] = (15,8)
chart = sns.barplot(x='Location', 
            y='salary', 
            data=df,
           ci = None
           )
chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'New York, NY'),
#  Text(1, 0, 'Plano, TX'),
#  Text(2, 0, 'Remote'),
#  Text(3, 0, 'Durham, NC'),
#  Text(4, 0, 'Redmond, WA'),
#  Text(5, 0, 'Seattle, WA'),
#  Text(6, 0, 'Louisville, CO'),
#  Text(7, 0, 'Indianapolis, IN'),
#  Text(8, 0, 'Austin, TX'),
#  Text(9, 0, 'Brooklyn, NY'),
#  Text(10, 0, 'Woonsocket, RI'),
#  Text(11, 0, 'Parsippany, NJ'),
#  Text(12, 0, 'Whitestone, NY'),
#  Text(13, 0, 'Nashville, TN'),
#  Text(14, 0, 'Portland, OR'),
#  Text(15, 0, 'Los Angeles, CA'),
#  Text(16, 0, 'White Plains, NY'),
#  Text(17, 0, 'Hershey, PA'),
#  Text(18, 0, 'Englewood, CO'),
#  Text(19, 0, 'Miami, FL'),
#  Text(20, 0, 'Dearborn, MI'),
#  Text(21, 0, 'Washington, DC'),
#  Text(22, 0, 'Wright Patterson AFB, OH'),
#  Text(23, 0, 'Sunnyvale, CA'),
#  Text(24, 0, 'San Francisco, CA'),
#  Text(25, 0, 'Fort Meade, MD'),
#  Text(26, 0, 'Milwaukee, WI'),
#  Text(27, 0, 'Fairfax, VA'),
#  Text(28, 0, 'Radnor, PA'),
#  Text(29, 0, 'Cambridge, MA'),
# ...

# %%
correlation = df[['Rating', 'salary', 'age', 'Python', 'SQL', 'Pandas', 'R Studio', 'Excel', 'AWS']].corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# %%
sns.heatmap(correlation, vmax=.3, center=0, cmap=cmap,
           square=True, linewidth=.5, cbar_kws={'shrink': .5})
# Out:
# <AxesSubplot:>
